# %% [markdown]
# <a href="https://colab.research.google.com/github/Awadhendrsingh/EDA-Project-Hotel-Booking-Analysis/blob/main/EDA_Project_Hotel_Booking_Analysis_%7C%7C_Awadhendra_Singh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Hotel Booking Analysis

# %% [markdown]
# ##### **Project Type**    - EDA
# ![do-binary-class-classification-in-python.jpg](data:image/jpeg;base64,...)
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The goal of this project is to analyze a hotel booking dataset using Python's Pandas, Matplotlib, Seaborn, and NumPy libraries. The dataset contains information about bookings for both a city hotel and a resort hotel, including details such as booking dates, length of stay, number of guests, and special requests. Develop
# visualisations and
# apply statistical
# techniques if required
# to test the
# assumptions . Drawing insights
# from the research like :- What were you
# able to learn from
# the analysis?
# Did your
# assumptions turn
# out to be right?
# How would your
# analysis be helpful
# to the
# stakeholders?
#
#
#
#
#
#
# Tools which we are going to use in this project are :-
#
#
#
#
#
# Pandas: Data manipulation and aggregation.
#
#
#
#
# Matplotlib and Seaborn: Data visualization.
#
#
#
# NumPy: Efficient array operations.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Awadhendrsingh/EDA-Project-Hotel-Booking-Analysis

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Have you ever wondered when the best time of year to book a hotel room is? Or the optimal length of stay in order to get the best daily rate? What if you wanted to predict whether or not a hotel was likely to receive a disproportionately high number of special requests? This hotel booking dataset can help you explore those questions! This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things. All personally identifying information has been removed from the data. Explore and analyse the data to discover important factors that govern the bookings.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The business objective, in the context of analyzing the hotel booking dataset, can vary based on the goals of the organization or individual involved. Here are a few potential business objectives that could guide the analysis:
#
# Optimizing Booking , Customer Segmentation ,Revenue Optimization , Operational Efficiency , etc.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Path to the CSV file
file_path = '/content/drive/MyDrive/Hotel Bookings.csv'

# %%
# Load the CSV file into a Pandas DataFrame
df = pd.read_csv(file_path)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %% [markdown]
# DATASET LINK

# %% [markdown]
# https://drive.google.com/file/d/1C9AxF9fcVzMw0Bgs0NaRrNML2WwX1Ehm/view

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count

rows, columns = df.shape
print(f"The dataset has {rows} rows and {columns} columns.")
# Out:
# The dataset has 119390 rows and 32 columns.

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
print("\nDataset information:")
print(df.info())
# Out:
# Dataset information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
duplicate_count = df.duplicated().sum()

# Display the count of duplicate rows
print(f"There are {duplicate_count} duplicate rows in the dataset.")
# Out:
# There are 31994 duplicate rows in the dataset.

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
# Display the count of missing values in each column
missing_values = df.isnull().sum()

# Display columns with missing values and their counts
missing_values = missing_values[missing_values > 0]
if not missing_values.empty:
    print("Columns with missing values:")
    print(missing_values)
else:
    print("No missing values in the dataset.")
# Out:
# Columns with missing values:
# children         4
# country        488
# agent        16340
# company     112593
# dtype: int64

# %%
# Visualizing the missing values
# !pip install missingno

# %%
# Visualizing the missing values
import missingno as msno

# Create a matrix to visualize missing values
msno.matrix(df)

# Display a bar chart to visualize missing values
msno.bar(df)
# Out:
# <Axes: >

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# After all the above case study on dataset I come across a solution that there are 119390 rows and 32 columns in the dataset with 31994 duplicate rows in it . There are also some columns with missing values in it ; The columns are - Company having 112593 no. of missings values , Agent with 16340 no. of missing values , Country with 488 no. of missing values and Children with 4 no. of missing values . And also find the no. of non null values in every column .

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df_column= df.columns
print(df_column)
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe
# Display summary statistics of the numeric columns
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# ![hotel_analysis_1_a60b375461.jpg](data:image/jpeg;base64,...)![hotel_analysis_2_398f3b14ea.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for column in df.columns:
    unique_values = df[column].unique()
    print(f"Unique values for {column}:\n{unique_values}\n")
# Out:
# Unique values for hotel:
# ['Resort Hotel' 'City Hotel']
#
# Unique values for is_canceled:
# [0 1]
#
# Unique values for lead_time:
# [342 737   7  13  14   0   9  85  75  23  35  68  18  37  12  72 127  78
#   48  60  77  99 118  95  96  69  45  40  15  36  43  70  16 107  47 113
#   90  50  93  76   3   1  10   5  17  51  71  63  62 101   2  81 368 364
#  324  79  21 109 102   4  98  92  26  73 115  86  52  29  30  33  32   8
#  100  44  80  97  64  39  34  27  82  94 110 111  84  66 104  28 258 112
#   65  67  55  88  54 292  83 105 280 394  24 103 366 249  22  91  11 108
#  106  31  87  41 304 117  59  53  58 116  42 321  38  56  49 317   6  57
#   19  25 315 123  46  89  61 312 299 130  74 298 119  20 286 136 129 124
#  327 131 460 140 114 139 122 137 126 120 128 135 150 143 151 132 125 157
#  147 138 156 164 346 159 160 161 333 381 149 154 297 163 314 155 323 340
#  356 142 328 144 336 248 302 175 344 382 146 170 166 338 167 310 148 165
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# lets check, which column has null values
missing_values[:5]
# Out:
# children         4
# country        488
# agent        16340
# company     112593
# dtype: int64

# %%
# drop column with maximum no. of missing values
df.drop(['company'], axis=1, inplace=True)

# %%
# As we can see there is minimal missing values in 'agent' column so replace it with 0
df['agent'].fillna(value = 0, inplace = True)
df['agent'].isnull().sum()
# Out:
# 0

# %%
# as there is less null values in 'country' so replace the null with'other' as country name
df['country'].fillna(value = 'others', inplace = True)
df['country'].isnull().sum()
# Out:
# 0

# %%
# check whether the dataset having any other null value
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          4
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# days_in_waiting_list              0
# customer_type                     0
# ...

# %%
# total stay in nights
df['total_stay_in_nights'] = df['stays_in_week_nights'] + df['stays_in_weekend_nights']
df['total_stay_in_nights']
# Out:
# 0         0
# 1         0
# 2         1
# 3         1
# 4         2
#          ..
# 119385    7
# 119386    7
# 119387    7
# 119388    7
# 119389    9
# Name: total_stay_in_nights, Length: 119390, dtype: int64

# %%
# Creat a new column 'revenu'
df['revenu'] = df['total_stay_in_nights'] * df['adr']
df['revenu']
# Out:
# 0            0.00
# 1            0.00
# 2           75.00
# 3           75.00
# 4          196.00
#            ...
# 119385     672.98
# 119386    1578.01
# 119387    1103.97
# 119388     730.80
# 119389    1360.80
# Name: revenu, Length: 119390, dtype: float64

# %%
# for better understanding of 'is_canceled' col replace the value from (0,1) to 'not_canceled' , 'canceled'
df['is_canceled'] = df['is_canceled'].replace([0,1], ['not_canceled', 'canceled'])
df['is_canceled']
# Out:
# 0         not_canceled
# 1         not_canceled
# 2         not_canceled
# 3         not_canceled
# 4         not_canceled
#               ...
# 119385    not_canceled
# 119386    not_canceled
# 119387    not_canceled
# 119388    not_canceled
# 119389    not_canceled
# Name: is_canceled, Length: 119390, dtype: object

# %%
# same as above for 'is_repeated_guest'
df['is_repeated_guest'] = df['is_repeated_guest'].replace([0,1] , ['not_repeated', 'repeated'])
df['is_repeated_guest']
# Out:
# 0         not_repeated
# 1         not_repeated
# 2         not_repeated
# 3         not_repeated
# 4         not_repeated
#               ...
# 119385    not_repeated
# 119386    not_repeated
# 119387    not_repeated
# 119388    not_repeated
# 119389    not_repeated
# Name: is_repeated_guest, Length: 119390, dtype: object

# %%
# Display the first few rows of the cleaned & transformed dataset
print("First few rows of the cleaned dataset:")
print(df.head())
# Out:
# First few rows of the cleaned dataset:
#           hotel   is_canceled  lead_time  arrival_date_year  \
# 0  Resort Hotel  not_canceled        342               2015
# 1  Resort Hotel  not_canceled        737               2015
# 2  Resort Hotel  not_canceled          7               2015
# 3  Resort Hotel  not_canceled         13               2015
# 4  Resort Hotel  not_canceled         14               2015
#
#   arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# 3               July                        27                          1
# 4               July                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  agent  \
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Following are all the manipulation and insights I have done :-
#
# >1. I have checked if there is any missing values / null values in the dataset. Then I found some columns such as 'company', 'agent', 'country' & 'children' have null values where column 'company' have the most no. of null values .
#
# >2. Then I drop the column with maximum no. of missing values i.e. column 'company' .
#
# >3. And then  columns which have less null values replace that columns with a specific value . As there is minimal missing values in 'agent' column so replace it with 0 . And as there is less null values in 'country' so replace the null with'other' as country name .
#
# >4. Then I check whether the dataset having any other null value in any column and I found that only the column 'children' have 4 null values ( which will not affect the dataset anymore ) and remaining all the columns have 0 null value .
#
# >5. Then I create a new feature (column) 'total_guests' by combining 'adults', 'children', and 'babies' columns togther .
#
# >6. Then I creat a new column 'total_stay_in_nights' by combining 'stays_in_weekend_nights' and 'stays_in_week_nights' column togther .
#
# >7. After that I have created a new column 'revenu' by multiplying the columns 'total_stay_nights' and 'adr'(Av. Daily Rates ) .
#
# >8. Then for better understanding of 'is_canceled' column replace the value from (0,1) to 'not_canceled' , 'canceled' and do the same with 'is_repeated_guests' .
#
# >9. After that display the first few rows of the cleaned & transformed dataset to check your wrangling .
#
# || Now the dateset is ready for vizualization and storytelling tasks ||

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code

# Booking distribution by hotel type

plt.figure(figsize=(10, 6))
sns.countplot(x='hotel', data=df, hue='total_stay_in_nights')
plt.title('Booking Distribution by Hotel Type')
plt.xlabel('Hotel Type')
plt.ylabel('Number of Bookings')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I pickup this chart to show comparision between 'Resort hotel' and 'City hotel' total no. of bookings .

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# After comparision between 'Resort hotel' and 'City hotel' total no. of bookings I found that total stay in nights in 'City hotel' is much more than that in 'Resort hotel' .

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes , the gained insight helps creating a positive business impact . By the help of these hotel management look after the factors of 'Resort hotel' not being the first choice of most of the customers and improve that which will help in business growth .

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
plt.figure(figsize=(8, 8))
cancellation_counts = df['is_canceled'].value_counts()
plt.pie(cancellation_counts, labels=cancellation_counts.index, autopct='%1.1f%%', startangle=90, colors=['blue', 'red'])
plt.title('Distribution of Cancellations')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I pickup this chart to show the percentage or proportion of distribution of cancellation .

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Here I found that 37% of all the bookings got cancelled .

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gained insights help creating a positive business impact by:- optimizing booking strategies , improving customer experience , marketing and promotions , revenue management .

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code

# Monthly booking trends
plt.figure(figsize=(12, 6))
sns.countplot(x='arrival_date_month', data=df, hue='total_stay_in_nights', order=['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'])
plt.title('Monthly Booking Trends')
plt.xlabel('Month')
plt.ylabel('Number of Bookings')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To compare the total no. of bookings with respect to months .

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insight I found is that the bookings increases from January to May , and the most no. of bookings are in the May month . And no. bookings slowed down a little bit from June to October and from November to February decreases rapidly and it is lowest in December .

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, as we can see the bookings get slowed down as the winter approaches . So, by the help of this visualization hotel management will improve there booking criteria by compromising with rates and do promotional activites .

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code

# Length of stay distribution
plt.figure(figsize=(12, 6))
sns.histplot(x='stays_in_weekend_nights', data=df, bins=20, kde=True, label='Weekend Nights')
sns.histplot(x='stays_in_week_nights', data=df, bins=20, kde=True, label='Week Nights')
plt.title('Distribution of Length of Stay')
plt.xlabel('Length of Stay (Nights)')
plt.ylabel('Number of Bookings')
plt.legend()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To clearly show the distribution of length of stay in week nights and weekend nights .

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights found from the chart are:-
#
# >1. No. of bookings for one night is much more higher in weekend nights as compare to week nights .
#
# >2. For stay upto 2 to 5 days the no. of bookings is higher in week nights as compare to weekend nights .
#
# >3. For long stay no. of week days bookings are more .
#
# >4. As the length stay increases the no. of bookings decreases . Most of the bookings are between 1 to 3 nights stay .

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gained insights help creating a positive business impact . By knowing the fact that most of the bookings are for upto 3 nights stays hotel management can give discount on 1 week stay to make a great revenue in long stays .

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
# Distribution of total special requests
sns.histplot(df['total_of_special_requests'], kde=True)
plt.title('Distribution of Total Special Requests')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This plot will show the distribution of the total special requests made by guests. The histogram will give an idea of the frequency of different levels of special requests .

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The "Distribution of Total Special Requests" chart provides insights into the frequency and distribution of special requests made by guests during hotel bookings. Here are some insights :-
#
# >1. Most Guests Do Not Make Special Requests: The majority of the bars in the histogram are concentrated towards zero, it suggests that a significant portion of guests does not make any special requests during their bookings .
#
# >2. Tail Distribution: There is a long tail to the right, it suggests that some guests make a large number of special requests. This could be valuable information for hotel management to understand the needs and preferences of a specific group of guests.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# By knowing the frequency and nature of special requests, the hotel management can optimize operational processes. For example, if a specific type of special request is highly common, the hotel can streamline its operations to efficiently handle such requests without causing inconvenience to guests. But in this case there is no negative or positive impact because the peak at 0 indicates that most of the guests does not make any special requests .

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code

# Distribution of customer types
sns.countplot(x='customer_type', data=df)
plt.title('Distribution of Customer Types')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart will provide a visual representation of the distribution of customers across different types. Each bar represents the count of occurrences for each customer type.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Here are some insights :-
#
# >1. Proportion of Customer Types: In this case the height of the bar is tallest in Transient customer type and then in Transient-party but comparatively very low than Transient . It shows that most of the proportion of customer type are from Transient .
#
# >2. Targeted Marketing Opportunities: Depending on the distribution, the hotel can tailor marketing strategies to target specific customer types.
#
# >3. Understanding Customer Demographics: Insights into the distribution of customer types can aid in understanding the demographics and preferences of the hotel's clientele.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive impact :-
#
# Understanding the distribution of customer types allows the hotel to tailor its services to better meet the specific needs and preferences of each customer segment. This can lead to higher customer satisfaction and loyalty.
#
#
#
# With a clear understanding of the dominant customer types, the hotel can enhance the overall customer experience by customizing services, amenities, and communication channels according to the preferences of each segment .
#
# Negative impact :-
#
# If the distribution remains static over time, the hotel may miss opportunities to adapt to emerging trends or changes in customer behavior. Continuous monitoring and adaptation are crucial to staying competitive.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code

#  Average booking changes by hotel type
sns.barplot(x='hotel', y='booking_changes', data=df)
plt.title('Average Booking Changes by Hotel Type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart will provide a visual representation of the average number of booking changes for each hotel type.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Here are some insights :-
#
# Compare the heights of the bars for each hotel type. There are notable differences, it indicates variations in the average number of booking changes between the city hotel is lower than the resort hotel.
#
# As Resort hotel experiences significantly more booking changes, the hotel management can make operational adjustments to accommodate these changes more efficiently.
#
# Due to higher average booking changes I suggest a need for more flexible cancellation policies or improved communication about booking modifications to enhance the guest experience in Resort hotel .

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Impact on Revenue: Consider how booking changes might impact revenue. More changes could lead to increased uncertainty, and the Resort hotel might need strategies to mitigate potential revenue loss.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
# Display the distribution of bookings across different distribution channels
plt.figure(figsize=(12, 6))
sns.countplot(x='distribution_channel', data=df)
plt.title('Distribution of Bookings by Channel')
plt.xlabel('Distribution Channel')
plt.ylabel('Number of Bookings')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To show the number of bookings for each distribution channel.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This is clearly visible that TA/TO(Tour of Agent/ Tour of Operator) has the most no. of bookings . And undefined & GDS have least or not have any bookings .

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive impact :-
#
# Identifying High-Performing Channels:
#
#  TA/TO distribution channel stands out with significantly more bookings, it suggests that the channel is effective in attracting customers.
# Business Impact: Allocate more resources and marketing efforts to this high-performing channels to maximize bookings.
#
#
# Negative impact :-
#
# Underperforming Channels:
#
#  Channels such as Direct & Corporate are consistently have lower bookings and undefined and GDS have not any bookings, it may indicate that these channels are not effective in attracting customers.
# Business Impact: Evaluate the effectiveness of marketing strategies on these channels and consider adjustments or reallocation of resources.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
# Display the distribution of bookings across different market segments
plt.figure(figsize=(12, 6))
sns.countplot(x='market_segment', data=df, hue='market_segment')
plt.title('Distribution of Bookings by Market Segment')
plt.xlabel('Market Segment')
plt.ylabel('Number of Bookings')
plt.xticks(rotation=45)
plt.legend(title='Market Segment', loc='upper right')  # Add a legend for better clarity
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To display the distribution of bookings across different market segments .

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The Online TA market segment has been used most frequently to book a hotel by the guests . After that Offline TA/TO , Groups , Direct , Corporate are the most frequent respectively .

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive impact :-
#
# Identifying Profitable Segments:
#
# Online TA market segments contribute significantly to the number of bookings, it indicates the business in this area is performing well.
# Business Impact: Allocate resources, marketing efforts, and tailored promotions to further attract and retain customers from this profitable segments.
#
# Understanding Preferences:
#
# Different market segments may have distinct preferences and needs. Understanding these preferences allows for personalized marketing strategies.
# Business Impact: Tailor services, promotions, and communication to better suit the preferences of each market segment, enhancing customer satisfaction.
#
# Negative impact :-
#
# Underperforming Segments:
#
# The market segments that consistently have lower bookings or show a declining trend, it may signal challenges in attracting customers from those segments.
# Business Impact: Investigate the reasons behind the underperformance and consider adjustments to marketing strategies or service offerings for those segments.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
#To display the average daily rate (ADR) of the hotel

#Calculate average daily rate (ADR) for each hotel type
adr_by_hotel = df.groupby('hotel')['adr'].mean().reset_index()

# Set up colors for each bar
colors = sns.color_palette("pastel", n_colors=len(adr_by_hotel))

# Plotting the bar chart
plt.figure(figsize=(8, 6))
sns.barplot(x='hotel', y='adr', data=adr_by_hotel, palette=colors)
plt.title('Average Daily Rate (ADR) by Hotel')
plt.xlabel('Hotel')
plt.ylabel('Average Daily Rate (ADR)')
plt.show()
# Out:
# <ipython-input-64-6cb3a1578c0b>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='hotel', y='adr', data=adr_by_hotel, palette=colors)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To display the average daily rate (ADR) of the hotel .

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart allows for a visual comparison of the average daily rates between different City hotel & Resort hotel
# It Identify that City hotel consistently has a higher average daily rate compared to the Resort hotel . This insight can be crucial for pricing strategies.Understanding the ADR of each hotel type helps in assessing the competitive positioning of the hotels in the market.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Aligning ADR with the perceived value and quality can enhance competitive positioning . Strategic pricing adjustments can lead to revenue maximization.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
# Display total revenue of the hotels
plt.figure(figsize=(8, 5))
sns.barplot(x='hotel', y='revenu', data=df, estimator=sum)
plt.title('Total Revenue of Hotels')
plt.xlabel('hotel Type')
plt.ylabel('Total Revenue')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To display total revenue of the City hotel and Resort hotel .

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# City hotel significantly outperforms the Resort in terms of revenue, it might prompt further investigation into the factors contributing to this difference. This could include factors such as location, amenities, or pricing strategies.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# City hotel consistently brings in higher revenue, pricing strategies can be adjusted accordingly. This might involve premium pricing of City hotel , or promotions and discounts for the Resort hotel to boost its performance.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
# Meal preferences by hotel type
plt.figure(figsize=(10, 6))
sns.countplot(x='meal', hue='hotel', data=df)
plt.title('Meal Preferences by Hotel Type')
plt.xlabel('Meal Type')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To display meal preferences of City hotel and Resort hotel .

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# BB meal is the most frequently ordered food by both the hotels and all the different meal have very less in demand .

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive impact :-
#
# Understanding meal preferences allows hotels to tailor their menu offerings to better match customer expectations. This can lead to increased customer satisfaction and loyalty.
#
# Negative impact :-
#
# As the analysis solely focuses on the most popular meals i.e. BB , there is a risk of offering a limited variety. This may lead to customer dissatisfaction, especially for guests with diverse dietary preferences or restrictions.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
# Calculate the total number of guests for weeknights and weekend nights
total_weeknight_guests = df[df['stays_in_week_nights'] > 0]['adults'].sum() + df[df['stays_in_week_nights'] > 0]['children'].sum() + df[df['stays_in_week_nights'] > 0]['babies'].sum()
total_weekend_guests = df[df['stays_in_weekend_nights'] > 0]['adults'].sum() + df[df['stays_in_weekend_nights'] > 0]['children'].sum() + df[df['stays_in_weekend_nights'] > 0]['babies'].sum()

# Calculate the percentage of guests for weeknights and weekend nights
percentage_weeknight_guests = total_weeknight_guests / (total_weeknight_guests + total_weekend_guests) * 100
percentage_weekend_guests = total_weekend_guests / (total_weeknight_guests + total_weekend_guests) * 100

# Pie chart for the percentage of guests in weeknights and weekend nights
labels = ['Weeknights', 'Weekend Nights']
sizes = [percentage_weeknight_guests, percentage_weekend_guests]
colors = ['lightblue', 'lightcoral']

plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, colors=colors)
plt.title('Percentage of Guests in Weeknights vs. Weekend Nights')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To visualize percentage of guests in week nights and weekend nights .

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart indicates that a higher percentage of guests stay during weeknights compared to weekend nights. This suggests that the hotel experiences more occupancy during weekdays. While weeknights dominate in terms of guest percentages, it also highlights an opportunity to attract more guests during weekends.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Adjusting pricing strategies, packages, and amenities based on the occupancy patterns can optimize revenue. For instance, offering special weekend packages or promotions could attract more leisure travelers, contributing to increased revenue.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
correlation_matrix = df.corr()
plt.figure(figsize=(15, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
# Out:
# <ipython-input-57-faeb73498c7f>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This heatmap can help identify relationships between different numerical variables in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Positive Correlations:
#
# Positive correlations between the length of stay and other variables like the number of adults, children, or babies might suggest that longer stays are associated with larger groups or families. Positive correlations with total special requests could imply that guests with longer stays tend to make more special requests.
#
# Negative Correlations :
#
# A negative correlation between previous bookings and cancellations might indicate that guests with a history of bookings are less likely to cancel.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive correlations between total special requests and other variables may highlight the importance of catering to specific customer needs. This can contribute to higher customer satisfaction and positive reviews.
#
# It's important to note that correlations do not imply causation, and additional analysis may be needed to understand the underlying factors influencing these relationships.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
pairplot_data = df[['lead_time', 'stays_in_week_nights', 'stays_in_weekend_nights']]

# Create pair plot
sns.set(style="ticks")
sns.pairplot(pairplot_data, palette='viridis')
plt.suptitle('Pair Plot for Lead Time and Length of Stays', y=1.02)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# In this scenario, we're visualizing the relationships between "lead_time," "stays_in_week_nights," and "stays_in_weekend_nights." The pair plot will show scatterplots for each combination of these variables, histograms along the diagonal, and the relationships between variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Lead Time vs. Weeknight Stays:
#
# Insight: There might be a scattered pattern indicating that the lead time does not consistently correlate with the length of stays during weekdays.
#
# Lead Time vs. Weekend Stays:
#
# Insight: Similar to weeknight stays, there is a scattered pattern, suggesting that lead time may not have a strong influence on the length of stays during weekends.
#
# The histograms along the diagonal show the distribution of each variable individually.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Impact: Understanding that lead time doesn't strongly correlate with the length of stays can help in optimizing operational processes.
# By recognizing that guests may have varied lead times for different stay durations, the hotel can optimize staffing, room turnover, and resource allocation more efficiently.
#
# Negative Impact: Ignoring outliers or anomalies in the pair plot may result in missed opportunities for revenue growth.
# Anomalies could represent unique guest behaviors or preferences that, if understood and addressed, could lead to innovative offerings and increased customer satisfaction.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Understanding the distribution of bookings by month and other factors can guide the client in tailoring marketing campaigns to specific seasons, events, or customer segments.
#
#  Recognizing that different guest segments may have distinct preferences can lead to the creation of diversified offerings. For example, special promotions or packages for both business travelers with shorter lead times and leisure travelers planning longer stays.
#
# These recommendations are tailored to the insights gained from the visualizations and are aimed at helping the client align their business strategies with customer behaviors, optimize operational efficiency, and enhance the overall guest experience.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# 1. City hotel has more bookings than Resort hotel . It might be possible because of good location of City hotel and more promotional activities are done .
#
# 2. Monthly booking trends showe that the bookings increases from January to May , and the most no. of bookings are in the May month . And no. bookings slowed down a little bit from June to October and from November to February decreases rapidly and it is lowest in December .
#
# 3. Length of stay duration shows that no. of bookings for one night is much more higher in weekend nights as compare to week nights .
# For stay upto 2 to 5 days the no. of bookings is higher in week nights as compare to weekend nights .
# For long stay no. of week days bookings are more .
# As the length stay increases the no. of bookings decreases . Most of the bookings are between 1 to 3 nights stay .
#
# 4. Distribution by market segment shows that the TA/TO(Tour of Agent/ Tour of Operator) has the most no. of bookings . And undefined & GDS have least or not have any bookings .
#
# 5. Average Daily Rates(ADR) by hotels shows that City hotel consistently has a higher average daily rate compared to the Resort hotel .
#
# 6. City hotel consistently brings in higher revenue, pricing strategies can be adjusted accordingly. This might involve premium pricing of City hotel , or promotions and discounts for the Resort hotel to boost its performance.
#
# 7. Meals offer by both the hotels shows that BB meal is the most frequently ordered food by both the hotels and all the different meal have very less in demand .
#
# 8. The chart having titel Percentage of Guests in Weeknights vs. Weekend Nights indicates that a higher percentage of guests stay during weeknights compared to weekend nights. This suggests that the hotel experiences more occupancy during weekdays. While weeknights dominate in terms of guest percentages, it also highlights an opportunity to attract more guests during weekends.
#
# 9. Positive correlations between the length of stay and other variables like the number of adults, children, or babies might suggest that longer stays are associated with larger groups or families. Positive correlations with total special requests could imply that guests with longer stays tend to make more special requests.
#
# 10. A negative correlation between previous bookings and cancellations might indicate that guests with a history of bookings are less likely to cancel.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
